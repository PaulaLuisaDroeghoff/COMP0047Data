# %% [markdown]
# Loading data sets

# %%
import pandas as pd

# Replace 'your_file.parquet' with the actual file path
file_path_april = "/Users/pauladroghoff/Documents/UCL/COMP0047-Data Science/Coursework/COMP0047 Data/20220401-corporate_and_sovereign_bonds_pricing_data.parquet"
file_path_instrument = "/Users/pauladroghoff/Documents/UCL/COMP0047-Data Science/Coursework/COMP0047 Data/20220401-Instrument_Rating_reference_data.parquet"
file_path_organisation = "/Users/pauladroghoff/Documents/UCL/COMP0047-Data Science/Coursework/COMP0047 Data/20220401-Organisation_Rating.parquet"
# Read the file
df_april = pd.read_parquet(file_path_april, engine="pyarrow") 
df_instrument = pd.read_parquet(file_path_instrument, engine="pyarrow")
df_organisation = pd.read_parquet(file_path_organisation, engine="pyarrow")

# Display the first few rows
print(df_april.head())
print(df_instrument.head())
print(df_organisation.head())
# Out:
#          Date  Batch          ISIN      CUSIP Ticker Short_name_of_Issuer  \
# 0  2022-04-01  L1600  UG0000001400       None  REPOF        Rep of Uganda
# 1  2022-04-01  L1600  UG0000001533  V3843WBU3  REPOF        Rep of Uganda
# 2  2022-04-01  L1600  UG0000001293  V68921AN1  REPOF        Rep of Uganda
# 3  2022-04-01  L1600  UG0000001244  V68921AF8  REPOF        Rep of Uganda
# 4  2022-04-01  L1600  UG0000001764       None  REPOF        Rep of Uganda
#
#   Currency     Classification                  Region    Tier  ...    30YYTM  \
# 0      UGX  GovernmentRelated  EuropeMiddleEastAfrica  SNRFOR  ...  16.39225
# 1      UGX  GovernmentRelated  EuropeMiddleEastAfrica  SNRFOR  ...  16.39225
# 2      UGX  GovernmentRelated  EuropeMiddleEastAfrica  SNRFOR  ...  16.39225
# 3      UGX  GovernmentRelated  EuropeMiddleEastAfrica  SNRFOR  ...  16.39225
# 4      UGX  GovernmentRelated  EuropeMiddleEastAfrica  SNRFOR  ...  16.39225
#
# ...
